# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline
pyplot.rcParams['font.family'] = 'serif'
pyplot.rcParams['font.size'] = 12

nu = 1
x1 = 0.1
x2 = 1.
x3 = 2.

data_x01 = numpy.loadtxt('data_x01.txt')
data_x1 = numpy.loadtxt('data_x1.txt')
data_x2 = numpy.loadtxt('data_x2.txt')

y1 = data_x01[:,0]
v1 = data_x01[:,1]
y2 = data_x1[:,0]
v2 = data_x1[:,1]
y3 = data_x2[:,0]
v3 = data_x2[:,1]

pyplot.plot(v1+x1,y1,c='k',ls='-')
pyplot.plot(v2+x2,y2,c='k',ls='-')
pyplot.plot(v3+x3,y3,c='k',ls='-')

#pyplot.hlines(4, 0,3)
